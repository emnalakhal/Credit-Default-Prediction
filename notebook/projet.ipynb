# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Configuration esthétique
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("husl")

# Chargement des données
df = pd.read_csv('/mnt/agents/upload/cs-training.csv', index_col=0)

# Renommage des colonnes pour plus de clarté
df.columns = ['SeriousDlqin2yrs', 'RevolvingUtilization', 'Age', 
              'Num30_59DaysPastDue', 'DebtRatio', 'MonthlyIncome',
              'NumOpenCreditLines', 'Num90DaysLate', 'NumRealEstateLoans',
              'Num60_89DaysPastDue', 'NumDependents']

print("=" * 70)
print("ÉTAPE 1 : EXPLORATORY DATA ANALYSIS (EDA) COMPLÈTE")
print("=" * 70)
print(f"\n📊 DIMENSIONS DU DATASET : {df.shape[0]:,} observations × {df.shape[1]} variables")
print(f"\n{'Variable':<30} {'Type':<15} {'Description'}")
print("-" * 70)
descriptions = {
    'SeriousDlqin2yrs': 'Variable cible (1=défaut, 0=non-défaut)',
    'RevolvingUtilization': 'Taux d\'utilisation des lignes de crédit',
    'Age': 'Âge du demandeur',
    'Num30_59DaysPastDue': 'Nb de retards 30-59 jours (2 ans)',
    'DebtRatio': 'Ratio dette/revenu mensuel',
    'MonthlyIncome': 'Revenu mensuel ($)',
    'NumOpenCreditLines': 'Nb de lignes de crédit ouvertes',
    'Num90DaysLate': 'Nb de retards 90+ jours',
    'NumRealEstateLoans': 'Nb de prêts immobiliers',
    'Num60_89DaysPastDue': 'Nb de retards 60-89 jours',
    'NumDependents': 'Nb de personnes à charge'
}
for col, desc in descriptions.items():
    dtype = 'Numérique' if df[col].dtype in ['float64', 'int64'] else 'Catégorielle'
    print(f"{col:<30} {dtype:<15} {desc}")
